# %%
using Plots, Distributions
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\lucy_\.julia\compiled\v1.1\Distributions\xILW0.ji for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# └ @ Base loading.jl:1184

# %%
x = 1:100
plot(x,sqrt.(100 .-x))

# %%
R = 100
θdist = Uniform(0, 2pi)
rdist = Uniform(0,1)
# Out:
# Uniform{Float64}(a=0.0, b=1.0)

# %%
histogram(r)

# %%
θ = rand(θdist,1000)
r = R*sqrt.(rand(rdist,1000));

# %%
histogram2d(θ,r)

# %%
scatter(θ,r,proj=:polar)

# %%
#p1 = scatter(θ,r,proj=:polar)
#p2 = 
histogram2d(θ,r, m=2)
#plot(p1,p2)

# %%
t = 1:50
plot(t,(sqrt.(100 .- (t))).^2)
